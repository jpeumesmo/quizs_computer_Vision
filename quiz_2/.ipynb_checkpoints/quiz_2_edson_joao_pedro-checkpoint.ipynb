# %% [markdown]
# # Quiz 2 #
#
# **Nome:**  Edson Roteia e João Pedro Moreira Ferreira

# %% [markdown]
# ### First estimation - Manual Calculating from single image###
#
# - Configuration for naive estimation
#
# ![](./imgs/chess.jpg.png)
#
# - Size in pixel of the book:
#    - width: 870px
#    - heigth: 696px
#
#
# From the equations:
# $f_x = \frac{d_x}{d_X} d_z, f_y = \frac{d_y}{d_Y} d_z $ (1)
#
# We have:
# $f_x = \frac{870}{294} 1200, f_y = \frac{696}{234}1200$
#
# So:
# $f_x = 3551.02, f_y = 3569.23$

# %% [markdown]
# ### Second estimation - Using MATLAB App (Camera Calibrator)###
#
# - Input images to estimate camera parameters
#
# ![](./imgs/input_matlab.png)
#
#
# - Camera Calibrator App for MATLAB
#
# ![](./imgs/app.png)
#
#
# - Camera parameters estimate by the MATLAB App
#
# ![](./imgs/matlab_5.png)
#
# The Camera Calibrator MATLAB App Estimate the follow parameters:
#    - Intrisic Parameters:
#
#    - Extrinsic Parameters:
#
# ![](./imgs/extrinsicfinal.png)

# %% [markdown]
# ### Last Estimation - Using SVD

# %% [markdown]
# #### 1. Measure the 3-D coordinates of each vector of the n squares on the calibration pattern in the world reference frame.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


##read images
# images_name = ['./imgs/IMG_20190404_153953657.jpg','./imgs/IMG_20190404_153954488.jpg','./imgs/IMG_20190404_154000947.jpg',
#               './imgs/IMG_20190404_154002764.jpg','./imgs/IMG_20190404_154004200.jpg']
# images_name = ['./imgs/IMG_20190404_153953657.jpg','./imgs/IMG_20190404_153954488.jpg','./imgs/IMG_20190404_154004200.jpg']
images_name = ['./imgs/IMG_20190404_153953657.jpg']
images = []
for img_name in images_name:
    img = cv2.imread(img_name)
    images.append(img)

##find chessboard
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 28, 0.001)
objp = np.zeros((5*7,3), np.float32)
objp[:,:2] = np.mgrid[0:7,0:5].T.reshape(-1,2)

objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.





# 8. Set up A and b of system (6.14), and use (6.15) to estimate T_{z} and f_{x}
#      - The output is formed by alpha, f_{x}, and the extrinsic parameters of the viewing camera.
for img in images:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Find the chess board corners
    ret, corners = cv2.findChessboardCorners(gray, (7,5), None)
    # If found, add object points, image points (after refining them)
    if ret == True:
        objpoints.append(objp)
        corners2 = cv2.cornerSubPix(gray,corners, (11,11), (-1,-1), criteria)
        imgpoints.append(corners)
        # Draw and display the corners
        cv2.drawChessboardCorners(img, (7,5), corners2, ret)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.show()
        cv2.imwrite('teste.png',img)

# %%
imagepoints =  ([2022,807],
                [2164,806],
                [2305,807],
                [2446,808],
                [2587,809],
                [2728,806],
                [2870,806],
                [2018,916],
                [2164,917],
                [2307,919],
                [2451,919],
                [2596,917],
                [2738,920],
                [2882,921],
                [2016,1035],
                [2164,1033],
                [2311,1036],
                [2457,1034],
                [2605,1035],
                [2752,1034],
                [2898,1034],
                [2013,1155],
                [2163,1154],
                [2319,1156],
                [2464,1155],
                [2613,1156],
                [2764,1156],
                [2915,1153],
                [2007,1281],
                [2163,1283],
                [2316,1282],
                [2470,1282],
                [2624,1282],
                [2777,1282],
                [2931,1282])
imagepoints = np.asarray(imagepoints)
imagepoints
# Out:
# array([[2022,  807],
#        [2164,  806],
#        [2305,  807],
#        [2446,  808],
#        [2587,  809],
#        [2728,  806],
#        [2870,  806],
#        [2018,  916],
#        [2164,  917],
#        [2307,  919],
#        [2451,  919],
#        [2596,  917],
#        [2738,  920],
#        [2882,  921],
#        [2016, 1035],
#        [2164, 1033],
#        [2311, 1036],
#        [2457, 1034],
#        [2605, 1035],
#        [2752, 1034],
#        [2898, 1034],
#        [2013, 1155],
#        [2163, 1154],
#        [2319, 1156],
#        [2464, 1155],
#        [2613, 1156],
#        [2764, 1156],
#        [2915, 1153],
#        [2007, 1281],
#        [2163, 1283],
#        [2316, 1282],
#        [2470, 1282],
#        [2624, 1282],
#        [2777, 1282],
#        [2931, 1282]])

# %% [markdown]
# #### 2. Find the coordinates in the image reference frame of each of the N vertices.

# %%
#####POINTS IN THE WORLD##########
worldpoints = []
#points in 1,2,3,4,5,6,7
# worldpoints = objpoints
#points i1n 0.028,0.056,0.084,0.112,0.140,0.168
for points in objpoints:
    worldpoints.append(points * 28)
worldpoints = worldpoints[0]

# %% [markdown]
# #### 3. Having the N correspondences between image and world points, compute the SVD of A (6.8). The solution is the column of V corresponding to the smallest singular value of A.
# ![](./imgs/trucco6.8.png)

# %%
# print('imgpoints',imgpoints,'\nwolrdpoitns',worldpoints)
# Create A matrix
A = []
for worldpoint,imagepoint in zip(worldpoints,imagepoints):
#     print('world',worldpoint_vector,'img',imagepoint)
    A_line = []
    A_line.append(imagepoint[0] * worldpoint[0])
    A_line.append(imagepoint[0] * worldpoint[1])
    A_line.append(imagepoint[0] * worldpoint[2])
    A_line.append(imagepoint[0])
    A_line.append(-imagepoint[1] * worldpoint[0])
    A_line.append(-imagepoint[1] * worldpoint[1])
    A_line.append(-imagepoint[1] * worldpoint[2])
    A_line.append(-imagepoint[1])
#         print (A_line)
    A.append(A_line)

    #     for worldpoint,img in zip(worldpoint_vector,imagepoint):
#         print(worldpoint[0][0],worldpoint[0][1], img)
#         A_line = []
#         A_line.append(imagepoint[0] * worldpoint[0][0])
#         A_line.append(imagepoint[0] * worldpoint[0][1])
#         A_line.append(imagepoint[0] * worldpoint[0][2])
#         A_line.append(imagepoint[0])
#         A_line.append(-imagepoint[1] * worldpoint[0][0])
#         A_line.append(-imagepoint[1] * worldpoint[0][1])
#         A_line.append(-imagepoint[1] * worldpoint[0][2])
#         A_line.append(-imagepoint[1])
# #         print (A_line)
#         A.append(A_line)

A = np.asarray(A)
# U, D, V = np.linalg.svd(np.dot(np.transpose(A), A), full_matrices=True, compute_uv=True)
# U, D, V = np.linalg.svd(np.dot(A, np.transpose(A)), full_matrices=True, compute_uv=True)

U, D, V = np.linalg.svd(A, full_matrices=True, compute_uv=True)
# D = D[np.nonzero(D)]

# D = D**2

print ("D",D)
print ("\nV",V)
# idx_min = np.argmin(D)
idx_min = np.where(D == 0)[0]
# print(idx_min)
V_selected = V[idx_min][0]
# V_selected = U[:,idx_min]
# V_selected = V[:,idx_min]
print (V_selected)
# print(V)
# print(U)
# print('*****\n',worldpoints)
# print(U.shape,V.shape)
# Out:
# D [1.95314632e+06 7.06622310e+05 6.78241213e+04 2.76353071e+04
#  5.69187905e+03 8.32937357e+00 4.98756835e-12 0.00000000e+00]
#
# V [[-3.19962902e-01 -1.95581002e-01  0.00000000e+00 -2.79012545e-03
#    8.17973383e-01  4.36161743e-01  0.00000000e+00  6.81955545e-03]
#  [ 6.49080244e-02 -4.25904855e-01  0.00000000e+00 -2.53171797e-03
#   -4.82957805e-01  7.62321066e-01  0.00000000e+00  1.98584663e-03]
#  [-7.48817577e-01  5.66618416e-01 -1.37043155e-16  1.70435096e-02
#   -2.69049119e-01  2.10027749e-01  0.00000000e+00 -3.77656246e-02]
#  [-5.74858931e-01 -6.77697893e-01  2.77555756e-17  1.30569360e-02
#   -1.57638331e-01 -4.29430878e-01  0.00000000e+00 -2.88369384e-02]
#  [ 4.70623347e-02 -4.65603079e-03  5.36723443e-15  3.69877792e-01
#    2.08334049e-02  1.02350251e-02  0.00000000e+00 -9.27585624e-01]
#  [ 2.29607985e-03 -7.64743374e-04  3.60299355e-14  9.28824666e-01
#   -2.65232625e-06  1.49507332e-03  0.00000000e+00  3.70508634e-01]
#  [ 3.64716885e-16 -2.11089225e-16 -1.00000000e+00  3.57371113e-14
#    1.35872910e-16  1.28322451e-17  0.00000000e+00  8.55243050e-15]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00]]
# [0. 0. 0. 0. 0. 0. 1. 0.]

# %%
gamma = (V_selected[0] ** 2 + V_selected[1] ** 2 + V_selected[2] ** 2 ) ** (1/2)
alfa = ((V_selected[4] ** 2 + V_selected[5] ** 2 + V_selected[6] ** 2 ) ** (1/2))/gamma
print(gamma, alfa)
# print (idx_min,D,D[np.nonzero(D)],D[idx_min]<D[idx_min-1])
# print ('-------')
# print (V_selected)
# print ("--------")
# print (V[0][idx_min],V[1][idx_min],V[2][idx_min],V[3][idx_min])
# print (V)
# Out:
# 0.0 inf
# /home/jpeumesmo/.virtualenvs/cv/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in double_scalars

# %% [markdown]
# #### 5. Recover the first two rows of R and the two first components of T from (6.9)
# ![](./imgs/trucco6.9.png)

# %%
r = np.ones(shape=(3,3))
t = np.ones(shape=(3,1))
r[1][0] = V_selected[0]/gamma
r[1][1] = V_selected[1]/gamma
r[1][2] = V_selected[2]/gamma
t[1] = V_selected[3]/gamma
r[0][0] = (V_selected[4]/alfa)/gamma
r[0][1] = (V_selected[5]/alfa)/gamma
r[0][2] = (V_selected[6]/alfa)/gamma
t[0] = (V_selected[7]/alfa)/gamma
# print (r,t)

# %% [markdown]
# #### 6. Compute the third row of R as the vector product of the first two rows estimated in the previous step, and enforce the orthogonality constraint on the estimate of R through SVD decomposition.

# %%
#inner = 0 | dot = r[:][3]
r[2,:] = np.cross(r[0,:],r[1,:])

print (r)
print (gamma,(gamma**2 *(r[1][0]**2 + r[1][1]**2 + r[1][2]**2)) ** (1/2),gamma ==(gamma**2 *(r[1][0]**2 + r[1][1]**2 + r[1][2]**2)) ** (1/2))
print (alfa*gamma,(alfa**2 *gamma**2 *(r[0][0]**2 + r[0][1]**2 + r[0][2]**2)) ** (1/2),alfa*gamma==(alfa**2*gamma**2 *(r[0][0]**2 + r[0][1]**2 + r[0][2]**2)) ** (1/2))
print (r[1][0]**2+r[1][1]**2+r[1][2]**2)
print (r[0][0]**2+r[0][1]**2+r[0][2]**2)
print (r[2][0]**2+r[2][1]**2+r[2][2]**2)
print("******************")
print (np.inner(r[2,:],r[0,:]),np.inner(r[2,:],r[1,:])) 
print("******************")
print (t)

# %% [markdown]
# ![](./imgs/extrinsic.png)

# %% [markdown]
# #### 7. Pick a point for which $(x - \sigma_{x})$ is noticeably different from 0. If inequality (6.12) is satisfied, reverse the sign of the first two rows of R and the first two components of T
# ![](./imgs/trucco6.12.png)

# %%
x_aux = imgpoints[0][1][0][0] * (r[0][0] * worldpoints[0][1][0] + r[0][1] * worldpoints[0][1][1] +
                                    r[0][2] * worldpoints[0][1][2] + t[0])

# print(x_aux,imgpoints[0][1][0]TT[0],imgpoints[0][1][0][1] )
if x_aux > 0:
    r[0,:] = -r[0,:]
    r[1,:] = -r[1,:]
    t[0:2] = -t[0:2]

A_2 = []
for worldpoint_vector,imagepoint_vector in zip(worldpoints,imgpoints):
    for worldpoint, imagepoint in zip(worldpoint_vector, imagepoint_vector):
        A_line = []
        A_line.append(imagepoint[0][0])
        A_line.append((r[0][0] * worldpoint[0] + r[0][1] * worldpoint[1] + r[0][2] * worldpoint[2] + t[0])[0])
        A_2.append(A_line)

b = []
for worldpoint_vector,imagepoint_vector in zip(worldpoints,imgpoints):
    for worldpoint, imagepoint in zip(worldpoint_vector, imagepoint_vector):
        b.append(-imagepoint[0][0] * (r[2][0] * worldpoint[0] + r[2][1] * worldpoint[1] + r[2][2] * worldpoint[2]))

# %% [markdown]
# $T_{z}$
# $f_{x}$

# %%
np.dot(np.dot(np.linalg.inv(np.dot(np.transpose(A_2), A_2)), np.transpose(A_2)), b)
# Out:
# array([-51.47743673, 570.96901053])

# %% [markdown]
# ### Fourth Estimation - OpenCV Calibration Function

# %%
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
print('mtx:',mtx,'\ndist:',
      dist,'\nrvecs',rvecs,'\ntvecs:',tvecs)
# Out:
# mtx: [[2.03903169e+04 0.00000000e+00 2.23274657e+03]
#  [0.00000000e+00 2.75140402e+03 1.35442643e+03]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
# dist: [[-3.84669311e+01 -2.88308021e+03 -2.08469545e+00  8.17084189e-01
#    1.17091786e+05]]
# rvecs [array([[-0.71470651],
#        [ 1.54493982],
#        [ 0.93534454]])]
# tvecs: [array([[ 2.14918356],
#        [-9.50870844],
#        [71.51115665]])]
