# %% [markdown]
# # Quiz 3
#
# #### Alunos: Edson Roteia Araujo Junior e João Pedro

# %% [markdown]
# ### Input Image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

original = cv2.imread('imgs/parrot.jpg')
img = cv2.cvtColor(cv2.resize(original,(640,480)),cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.xticks([]),plt.yticks([])
plt.title('Original Image') 
plt.show()

# %% [markdown]
# ### Image after corruption

# %% [markdown]
# ### Our Filter

# %% [markdown]
# ### Image after filters (Ours, Gaussian, Bilinear)

# %%
##ours
ours = cv2.filter2D(img,-1,kernel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-32a2691c95a0> in <module>()
#       1 ##ours
# ----> 2 ours = cv2.filter2D(img,-1,kernel)
#
# NameError: name 'kernel' is not defined

# %%
###gaussian
gaussian = cv2.GaussianBlur(img,(5,5),0)

# %%
###bilateral
bilateral = cv2.bilateralFilter(img,9,75,75)

# %%
###show images
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')

plt.subplot(131),plt.imshow(img)
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(gaussian)
plt.title('Gaussian'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(bilateral)
plt.title('Bilateral'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### 10 images with medium ISO

# %%
images_name = []
images = []
for img_name in images_name:
    images.append(cv2.imread(img_name).astype(float))

# %%
####AVERAGE IMAGE
average_img = np.zeros(images[0].shape)
for img in images:
    np.add(average_img,img)
average_img = average_img/len(images)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-101-05fc241d15a0> in <module>()
#       1 ####AVERAGE IMAGE
# ----> 2 average_img = np.zeros(images[0].shape)
#       3 for img in images:
#       4     np.add(average_img,img)
#       5 average_img = average_img/len(images)
#
# IndexError: list index out of range

# %%
####STANDARD DEVIATION

# %%
####AVERAGE NOISE

# %%
####FILTERING
